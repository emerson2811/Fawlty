# %%
import pandas
data_frame1 = pandas.read_csv("products.csv")
data_frame1
# Out:
#    Size  order_id product_name  product_price        customer_name  \
# 0   NaN     23234        Shoes            120         Adam Emerson
# 1   NaN     56745        Shirt             40            Dohui Kim
# 2   NaN     56745       Shorts             30         Sancho Panza
# 3   NaN     45675        Socks             10          Don Quixote
# 4   NaN     45675       FitBit            130      Santa Esmerelda
# 5   NaN     56745   Wristwraps             20       Chuck Mangione
# 6   NaN     86594   Shinguards             30    George Washington
# 7   NaN     23456         Nubs             10  Henry David Thoreau
#
#   product_category      _brand
# 0        Equipment  NewBalence
# 1          Clothes         Gap
# 2          Clothes        Puma
# 3          Clothes      Reebok
# 4        Equipment      FitBit
# 5        Equipment       Rogue
# 6        Equipment       Rogue
# 7        Equipment        Nubs

# %%
from pandas import DataFrame
data_frame1 = DataFrame(data_frame1, columns=['order_id', 'product_name', 'product_price', 'customer_name', 'product_category', '_brand'])
data_frame1
# Out:
#    order_id product_name  product_price        customer_name product_category  \
# 0     23234        Shoes            120         Adam Emerson        Equipment
# 1     56745        Shirt             40            Dohui Kim          Clothes
# 2     56745       Shorts             30         Sancho Panza          Clothes
# 3     45675        Socks             10          Don Quixote          Clothes
# 4     45675       FitBit            130      Santa Esmerelda        Equipment
# 5     56745   Wristwraps             20       Chuck Mangione        Equipment
# 6     86594   Shinguards             30    George Washington        Equipment
# 7     23456         Nubs             10  Henry David Thoreau        Equipment
#
#        _brand
# 0  NewBalence
# 1         Gap
# 2        Puma
# 3      Reebok
# 4      FitBit
# 5       Rogue
# 6       Rogue
# 7        Nubs

# %%
data_frame1 = data_frame1.drop('_brand', axis=1)
data_frame1
# Out:
#    order_id product_name  product_price        customer_name product_category
# 0     23234        Shoes            120         Adam Emerson        Equipment
# 1     56745        Shirt             40            Dohui Kim          Clothes
# 2     56745       Shorts             30         Sancho Panza          Clothes
# 3     45675        Socks             10          Don Quixote          Clothes
# 4     45675       FitBit            130      Santa Esmerelda        Equipment
# 5     56745   Wristwraps             20       Chuck Mangione        Equipment
# 6     86594   Shinguards             30    George Washington        Equipment
# 7     23456         Nubs             10  Henry David Thoreau        Equipment

# %%
data_frame1.sort_values(by='product_price')
# Out:
#    order_id product_name  product_price        customer_name product_category
# 3     45675        Socks             10          Don Quixote          Clothes
# 7     23456         Nubs             10  Henry David Thoreau        Equipment
# 5     56745   Wristwraps             20       Chuck Mangione        Equipment
# 2     56745       Shorts             30         Sancho Panza          Clothes
# 6     86594   Shinguards             30    George Washington        Equipment
# 1     56745        Shirt             40            Dohui Kim          Clothes
# 0     23234        Shoes            120         Adam Emerson        Equipment
# 4     45675       FitBit            130      Santa Esmerelda        Equipment

# %%
data_frame1.sum(numeric_only=True)
# Out:
# order_id         394869
# product_price       390
# dtype: int64
