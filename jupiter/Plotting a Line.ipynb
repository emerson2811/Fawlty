# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.arange(1,11)
y = 2 * x + 5
plt.title("Length of Arrow over Time")
plt.xlabel("Time")
plt.ylabel("Length of Arrow")
plt.plot(x,y)
plt.show()
